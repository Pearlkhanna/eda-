# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/sonikakhanna/Downloads/carprice.csv')

# %%
df.head()
# Out:
#    symboling               CarName fueltype aspiration doornumber  \
# 0          2           audi 100 ls      gas        std       four
# 1          0           peugeot 504      gas        std       four
# 2          3  mitsubishi outlander      gas      turbo        two
# 3          1         toyota corona      gas        std        two
# 4          2       toyota cressida      gas        std        two
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0        sedan        fwd          front       99.8      176.6  ...
# 1        wagon        rwd          front      114.2      198.9  ...
# 2    hatchback        fwd          front       95.9      173.2  ...
# 3    hatchback        fwd          front       95.7      158.7  ...
# 4  convertible        rwd          front       98.4      176.2  ...
#
#    enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# 0         109        mpfi       3.19   3.40             10.0         102
# ...

# %%
import seaborn as sns
sns.pairplot(df)

# %% [markdown]
# #some insights from data set

# %%
df['enginelocation'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='enginelocation'>

# %%
in cars most of the enginelocation is in the front

# %%
df.groupby('doornumber').mean()['price'].plot(kind='bar')
# Out:
# /var/folders/cf/6twhyzx56xj6q56wvg1n5qwm0000gn/T/ipykernel_57775/2648966147.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('doornumber').mean()['price'].plot(kind='bar')
# <Axes: xlabel='doornumber'>

# %%
here we can see price of 4 doornumber is highest and there are only two type of doornumbers and 2 doornumber is lowest

# %%
plt.scatter(df['horsepower'],df['citympg'])

# %%
the scatter plot is negatively skwed and is having negative relationshi between horsepower and citympg

# %%
df[['wheelbase', 'enginesize']].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# #in wheelbase we can see that most of the data set lies between the range of 100 and there are 2 outliers

# %% [markdown]
# #in enginesize most of the values lies between 100-150 and median is somewhere 130

# %%
df.groupby('carbody')['price'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='carbody'>

# %%
here there were 2 variables carbody and price, the price of convertable and hardtop is above 2500 where as the lowest price is of hatchback

# %%
colors = ['brown', 'grey','blue','orange','green']
df.groupby('carbody').mean()['carlength'].plot(kind='pie', colors=colors)
# Out:
# /var/folders/cf/6twhyzx56xj6q56wvg1n5qwm0000gn/T/ipykernel_57775/2676423608.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('carbody').mean()['carlength'].plot(kind='pie', colors=colors)
# <Axes: ylabel='carlength'>

# %%
herein we can see almost carlength and carbody have same connection there is no difference in the length as compared to body
